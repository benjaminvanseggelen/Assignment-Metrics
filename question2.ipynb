# %%
import pandas as pd
versions = ['5.0.6', '5.1.3', '5.2.1', '5.3.4', '5.4.5', '5.5.13.3']
for v in versions:
    df = pd.read_csv(f"ck-metrics/ck-metrics-{v}.csv")
    df_layer = pd.read_csv(f"le-metrics/le-metrics-{v}.csv")
    print(v)
    for i in range(len(df.max())):
        if df.min().index[i] == "ClassName":
            continue
        print(f"{df.min().index[i]}: {df.min()[i]} - {df.max()[i]}")
    for i in range(len(df_layer.max())):
        if df_layer.min().index[i] == "ClassName":
            continue
        print(f"{df_layer.min().index[i]}: {df_layer.min()[i]} - {df_layer.max()[i]}")
    print()
# Out:
# 5.0.6
# WMC: 0 - 176
# DIT: 1 - 6
# NOC: 0 - 42
# CBO: 0 - 86
# RFC: 0 - 436
# LCOM: 0 - 9082
# CA: 0 - 151
# NPM: 0 - 158
# layer: 0 - 13
#
# 5.1.3
# WMC: 0 - 176
# DIT: 1 - 6
# NOC: 0 - 31
# CBO: 0 - 86
# RFC: 0 - 438
# LCOM: 0 - 9533
# CA: 0 - 150
# NPM: 0 - 158
# layer: 0 - 12
#
# 5.2.1
# WMC: 0 - 181
# DIT: 1 - 6
# NOC: 0 - 31
# CBO: 0 - 86
# RFC: 0 - 438
# LCOM: 0 - 9533
# CA: 0 - 157
# NPM: 0 - 163
# layer: 0 - 12
#
# 5.3.4
# WMC: 0 - 195
# DIT: 1 - 6
# NOC: 0 - 32
# CBO: 0 - 89
# RFC: 0 - 455
# LCOM: 0 - 11261
# CA: 0 - 160
# NPM: 0 - 164
# layer: 0 - 12
#
# 5.4.5
# WMC: 0 - 208
# DIT: 1 - 6
# NOC: 0 - 34
# CBO: 0 - 94
# RFC: 0 - 499
# LCOM: 0 - 12393
# CA: 0 - 182
# NPM: 0 - 170
# layer: 0 - 17
#
# 5.5.13.3
# WMC: 0 - 249
# DIT: 1 - 6
# NOC: 0 - 34
# CBO: 0 - 102
# RFC: 0 - 561
# LCOM: 0 - 17152
# CA: 0 - 188
# NPM: 0 - 211
# layer: 0 - 18

# %%
# Out:
# ClassName    com.itextpdf.text.xml.xmp.XmpWriter
# WMC                                          176
# DIT                                            6
# NOC                                           42
# CBO                                           86
# RFC                                          436
# LCOM                                        9082
# CA                                           151
# NPM                                          158
# dtype: object
# ClassName    com.itextpdf.text.Anchor
# WMC                                 0
# DIT                                 1
# NOC                                 0
# CBO                                 0
# RFC                                 0
# LCOM                                0
# CA                                  0
# NPM                                 0
# dtype: object
# com.itextpdf.text.Anchor - com.itextpdf.text.xml.xmp.XmpWriter
# 0 - 176
# 1 - 6
# 0 - 42
# 0 - 86
# 0 - 436
# 0 - 9082
# 0 - 151
# 0 - 158
